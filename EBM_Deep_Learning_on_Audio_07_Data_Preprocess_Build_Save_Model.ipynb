# %% [markdown]
# # Deep Learning in Audio Classification in Python

# %% [markdown]
# ## Data Preprocessing and RNN Model Building and Saving Model

# %% [markdown]
# ```
# What's the Execution Plan?
# - The data is in the directory Dataset
#   - further in the directories: 'Train' 'Test' and 'Validation'
# - Each Set has two directories named by the dataset classes
#
# What's the dataset Size?
# - Its Big !!!
#
# Is it Big Data Problem?
# - Yes
#
# Do I have resources to use hadoop/aws?
# - no, I'm in Lockdown and limited time and knowledge is a concern for me!!
#
# What's the solution?
# - Have to use my old Intel i3 core :/ laptop to do some basic template
# - once I get internet access, I'll use the template to run on Google's Colab =')
# - After debugging, I'll increase the full dataset and re-run the program files for visualizaton, model training :O
# ```

# %% [markdown]
# ### Importing Libraries

# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.io import wavfile

# %%
from python_speech_features import mfcc

# %%
from tqdm import tqdm

# %%
from keras.layers import Conv2D, MaxPool2D, Flatten, Dropout, Dense
from keras.layers import LSTM, TimeDistributed

from keras.models import Sequential

from keras.utils import to_categorical

from sklearn.utils.class_weight import compute_class_weight

# %%
import pickle

from keras.callbacks import ModelCheckpoint

# %% [markdown]
# ### User Defined

# %%
class Config:
    def __init__(self, mode= 'conv', nfilt=26, nfeat=13, nfft = 2048, rate = 16000):
        self.mode = mode
        self.nfilt = nfilt
        self.nfeat = nfeat
        self.nfft = nfft
        self.rate = rate
        self.step = int(rate/10)
        self.model_path = os.path.join('models', mode + '.model')
        self.p_path = os.path.join('pickles', mode + '.p')

# %%
def check_data():
    if os.path.isfile(config.p_path):
        print('Loading existing data for {} model'.format(config.mode))
        with open(config.p_path, 'rb') as handle:
            tmp = pickle.load(handle)
            return tmp
    else:
        return None

# %%
def build_rand_feat():
    tmp = check_data()
    if tmp:
        return tmp.data[0], tmp.data[1]
        
    X = []
    y = []
    
    _min, _max = float('inf'), -float('inf')
    
    for _ in tqdm(range(n_samples)):
        
        rand_class = np.random.choice(class_dist.index, p = prob_dist)
        
        file = np.random.choice(df[df.Class==rand_class].index)
        
        rate, wav = wavfile.read(dataset_directory+str(rand_class)+"/"+str(file))
        Class = df.at[file, 'Class']
        
        rand_index = np.random.randint(0, wav.shape[0]-config.step)
        
        sample = wav[rand_index : rand_index + config.step]
        X_sample = mfcc(sample, rate, numcep=config.nfeat, nfilt=config.nfilt, nfft=config.nfft)
        
        _min = min(np.amin(X_sample), _min)
        _max = max(np.amax(X_sample), _max)
        
        X.append(X_sample)
        y.append(classes.index(Class))
        
    
    config.min = _min
    config.max = _max
    
    X, y = np.array(X), np.array(y)
    X = (X- _min) / (_max - _min)
    
    if config.mode == 'conv':
        X = X.reshape(X.shape[0], X.shape[1], X.shape[2], 1)
    elif config.mode =='time':
        X = X.reshape(X.shape[0], X.shape[1], X.shape[2])
    
    y = to_categorical(y, num_classes=2)
    
    config.data = (X, y)
    
    with open(config.p_path, 'wb') as handle:
        pickle.dump(config, handle, protocol=2)
    
    return X,y

# %%
def get_reccurent_model():
    ### Shape of data for RNN is (n, time, freq)
    model = Sequential()
    
    model.add(LSTM(128, return_sequences=True, input_shape=input_shape))
    model.add(LSTM(128, return_sequences=True))
    
    model.add(TimeDistributed(Dense(64, activation='relu')))
    model.add(TimeDistributed(Dense(32, activation='relu')))
    model.add(TimeDistributed(Dense(16, activation='relu')))
    
    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(16, activation='relu'))
    model.add(Dense(8, activation='relu'))
    model.add(Dense(2, activation='sigmoid'))
    model.summary()
    model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics=['acc'])
    
    return model

# %% [markdown]
# ## Data Extraction

# %%
os.listdir('Temp_Dataset/')
# Out:
# ['test', 'train', 'validation']

# %%
classes = list(os.listdir('Dataset/train/'))

print("Number of Classes in the Data Set:", len(classes), "Classes")
print("The classes of the dataset are   :", classes[0], ",", classes[1])
# Out:
# Number of Classes in the Data Set: 2 Classes
# The classes of the dataset are   : not_sick , sick

# %% [markdown]
# #### Creating the dataframe with basic column names

# %%
column_names = ['Fname','Class', 'Length']
df = pd.DataFrame(columns = column_names)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 0 entries
# Data columns (total 3 columns):
# Fname     0 non-null object
# Class     0 non-null object
# Length    0 non-null object
# dtypes: object(3)
# memory usage: 0.0+ bytes

# %%
# dataset_directory = 'Dataset/Train/'
dataset_directory = 'Temp_Dataset/train/'

# %%
for c in list(classes):
    print('Number of files in the directory \'{}\' are {}'.format(c,len(os.listdir(dataset_directory+c))))
# Out:
# Number of files in the directory 'not_sick' are 385
# Number of files in the directory 'sick' are 313

# %%
for c in list(classes):
    for n,f in tqdm(enumerate(os.listdir(dataset_directory+c))):
        rate, signal = wavfile.read(dataset_directory+str(c)+"/"+str(f))
        length = signal.shape[0]/rate
        f_df = pd.DataFrame({
            "Fname": str(f),
            "Class": str(c),
            "Length": length}, index = [n])
        df = df.append(f_df)
# Out:
# 385it [00:10, 35.03it/s]
# 313it [00:09, 34.20it/s]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 698 entries, 0 to 312
# Data columns (total 3 columns):
# Fname     698 non-null object
# Class     698 non-null object
# Length    698 non-null float64
# dtypes: float64(1), object(2)
# memory usage: 21.8+ KB

# %%
class_dist = df.groupby(['Class'])['Length'].mean()
class_dist
# Out:
# Class
# not_sick    4.999960
# sick        5.000198
# Name: Length, dtype: float64

# %%
df.set_index('Fname', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 698 entries, 02Sa2hBL_48_25_30.wav to _zrAnhgYzSo_15_20.wav
# Data columns (total 2 columns):
# Class     698 non-null object
# Length    698 non-null float64
# dtypes: float64(1), object(1)
# memory usage: 16.4+ KB

# %% [markdown]
# # RNN Model using LSTM

# %%
n_samples = 2 * int(df['Length'].sum()/0.1)
prob_dist = class_dist / class_dist.sum()
choices = np.random.choice(class_dist.index, p= prob_dist)

# %%
config = Config(mode = 'time')
config

# %%
X,y = build_rand_feat()
# Out:
# 100%|███████████████████████████████████| 69800/69800 [08:05<00:00, 143.68it/s]

# %%
y_flat = np.argmax(y, axis =1)

# %%
input_shape = (X.shape[1], X.shape[2])

# %%
model = get_reccurent_model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 3, 128)            72704
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 3, 128)            131584
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 3, 64)             8256
# _________________________________________________________________
# time_distributed_2 (TimeDist (None, 3, 32)             2080
# _________________________________________________________________
# time_distributed_3 (TimeDist (None, 3, 16)             528
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 48)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 48)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                784
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 136
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 18
# =================================================================
# Total params: 216,090
# Trainable params: 216,090
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Adding Checkpoints

# %%
checkpoint = ModelCheckpoint(config.model_path, monitor='val_acc', verbose=1, mode='max',
                            save_best_only=True, save_weights_only=False, period=1)

# %%
model.fit(X, y, epochs=250, batch_size=32, shuffle = True, validation_split=0.1, callbacks=[checkpoint])
# Out:
# Train on 62820 samples, validate on 6980 samples
# Epoch 1/250
# 62820/62820 [==============================] - 32s 516us/step - loss: 0.6932 - acc: 0.5042 - val_loss: 0.6924 - val_acc: 0.5307
#
# Epoch 00001: val_acc improved from -inf to 0.53073, saving model to models\time.model
# Epoch 2/250
# 62820/62820 [==============================] - 29s 467us/step - loss: 0.6903 - acc: 0.5344 - val_loss: 0.6914 - val_acc: 0.5287
#
# Epoch 00002: val_acc did not improve from 0.53073
# Epoch 3/250
# 62820/62820 [==============================] - 30s 473us/step - loss: 0.6868 - acc: 0.5419 - val_loss: 0.6852 - val_acc: 0.5407
#
# Epoch 00003: val_acc improved from 0.53073 to 0.54069, saving model to models\time.model
# Epoch 4/250
# 62820/62820 [==============================] - 30s 477us/step - loss: 0.6848 - acc: 0.5477 - val_loss: 0.6854 - val_acc: 0.5540
#
# Epoch 00004: val_acc improved from 0.54069 to 0.55401, saving model to models\time.model
# Epoch 5/250
# 62820/62820 [==============================] - 30s 477us/step - loss: 0.6830 - acc: 0.5503 - val_loss: 0.6811 - val_acc: 0.5504
#
# Epoch 00005: val_acc did not improve from 0.55401
# Epoch 6/250
# 62820/62820 [==============================] - 31s 489us/step - loss: 0.6813 - acc: 0.5541 - val_loss: 0.6827 - val_acc: 0.5578
#
# Epoch 00006: val_acc improved from 0.55401 to 0.55781, saving model to models\time.model
# Epoch 7/250
# 62820/62820 [==============================] - 31s 488us/step - loss: 0.6803 - acc: 0.5568 - val_loss: 0.6855 - val_acc: 0.5486
#
# Epoch 00007: val_acc did not improve from 0.55781
# Epoch 8/250
# 62820/62820 [==============================] - 31s 499us/step - loss: 0.6783 - acc: 0.5622 - val_loss: 0.6780 - val_acc: 0.5688
#
# Epoch 00008: val_acc improved from 0.55781 to 0.56884, saving model to models\time.model
# Epoch 9/250
# 62820/62820 [==============================] - 31s 495us/step - loss: 0.6753 - acc: 0.5702 - val_loss: 0.6710 - val_acc: 0.5797
#
# Epoch 00009: val_acc improved from 0.56884 to 0.57966, saving model to models\time.model
# Epoch 10/250
# 62820/62820 [==============================] - 31s 491us/step - loss: 0.6726 - acc: 0.5773 - val_loss: 0.6672 - val_acc: 0.5898
#
# Epoch 00010: val_acc improved from 0.57966 to 0.58983, saving model to models\time.model
# Epoch 11/250
# 62820/62820 [==============================] - 31s 490us/step - loss: 0.6679 - acc: 0.5869 - val_loss: 0.6639 - val_acc: 0.5953
#
# Epoch 00011: val_acc improved from 0.58983 to 0.59534, saving model to models\time.model
# Epoch 12/250
# 62820/62820 [==============================] - 31s 489us/step - loss: 0.6624 - acc: 0.5953 - val_loss: 0.6635 - val_acc: 0.5910
#
# Epoch 00012: val_acc did not improve from 0.59534
# Epoch 13/250
# 62820/62820 [==============================] - 31s 486us/step - loss: 0.6573 - acc: 0.6027 - val_loss: 0.6606 - val_acc: 0.5997
#
# Epoch 00013: val_acc improved from 0.59534 to 0.59971, saving model to models\time.model
# Epoch 14/250
# 62820/62820 [==============================] - 31s 488us/step - loss: 0.6533 - acc: 0.6088 - val_loss: 0.6557 - val_acc: 0.6016
#
# Epoch 00014: val_acc improved from 0.59971 to 0.60158, saving model to models\time.model
# Epoch 15/250
# 62820/62820 [==============================] - 31s 487us/step - loss: 0.6493 - acc: 0.6128 - val_loss: 0.6540 - val_acc: 0.6127
#
# Epoch 00015: val_acc improved from 0.60158 to 0.61268, saving model to models\time.model
# Epoch 16/250
# 62820/62820 [==============================] - 31s 488us/step - loss: 0.6436 - acc: 0.6217 - val_loss: 0.6514 - val_acc: 0.6229
#
# Epoch 00016: val_acc improved from 0.61268 to 0.62292, saving model to models\time.model
# Epoch 17/250
# 62820/62820 [==============================] - 30s 485us/step - loss: 0.6383 - acc: 0.6260 - val_loss: 0.6400 - val_acc: 0.6255
#
#
# Epoch 00032: val_acc improved from 0.70100 to 0.70415, saving model to models\time.model
# Epoch 33/250
# 62820/62820 [==============================] - 30s 474us/step - loss: 0.5213 - acc: 0.7270 - val_loss: 0.5499 - val_acc: 0.7076
#
# Epoch 00033: val_acc improved from 0.70415 to 0.70759, saving model to models\time.model
# Epoch 34/250
# 62820/62820 [==============================] - 30s 474us/step - loss: 0.5085 - acc: 0.7358 - val_loss: 0.5605 - val_acc: 0.6971
#
# Epoch 00034: val_acc did not improve from 0.70759
# Epoch 35/250
# 62820/62820 [==============================] - 30s 476us/step - loss: 0.5030 - acc: 0.7404 - val_loss: 0.5537 - val_acc: 0.7016
#
# Epoch 00035: val_acc did not improve from 0.70759
# Epoch 36/250
# 62820/62820 [==============================] - 30s 477us/step - loss: 0.4926 - acc: 0.7486 - val_loss: 0.5416 - val_acc: 0.7084
#
# Epoch 00036: val_acc improved from 0.70759 to 0.70838, saving model to models\time.model
# Epoch 37/250
# 62820/62820 [==============================] - 30s 473us/step - loss: 0.4836 - acc: 0.7558 - val_loss: 0.5304 - val_acc: 0.7186
#
# Epoch 00037: val_acc improved from 0.70838 to 0.71855, saving model to models\time.model
# Epoch 38/250
# 62820/62820 [==============================] - 30s 474us/step - loss: 0.4733 - acc: 0.7619 - val_loss: 0.5213 - val_acc: 0.7226
# Epoch 00038: val_acc improved from 0.71855 to 0.72256, saving model to models\time.model
# Epoch 39/250
# 62820/62820 [==============================] - 29s 467us/step - loss: 0.4657 - acc: 0.7668 - val_loss: 0.5115 - val_acc: 0.7282
#
# Epoch 00039: val_acc improved from 0.72256 to 0.72822, saving model to models\time.model
# Epoch 40/250
# 62820/62820 [==============================] - 29s 469us/step - loss: 0.4559 - acc: 0.7743 - val_loss: 0.5134 - val_acc: 0.7324
#
# Epoch 00040: val_acc improved from 0.72822 to 0.73245, saving model to models\time.model
# Epoch 41/250
# 62820/62820 [==============================] - 29s 469us/step - loss: 0.4490 - acc: 0.7777 - val_loss: 0.5234 - val_acc: 0.7269
#
# Epoch 00041: val_acc did not improve from 0.73245
# Epoch 42/250
# 62820/62820 [==============================] - 30s 477us/step - loss: 0.4385 - acc: 0.7842 - val_loss: 0.5046 - val_acc: 0.7386
#
# Epoch 00042: val_acc improved from 0.73245 to 0.73861, saving model to models\time.model
# Epoch 43/250
# 62820/62820 [==============================] - 30s 476us/step - loss: 0.4337 - acc: 0.7868 - val_loss: 0.5142 - val_acc: 0.7269
#
# Epoch 00043: val_acc did not improve from 0.73861
# Epoch 44/250
# 62820/62820 [==============================] - 30s 478us/step - loss: 0.4232 - acc: 0.7921 - val_loss: 0.4994 - val_acc: 0.7454
#
# Epoch 00044: val_acc improved from 0.73861 to 0.74542, saving model to models\time.model
# Epoch 45/250
# 62820/62820 [==============================] - 30s 472us/step - loss: 0.4133 - acc: 0.7997 - val_loss: 0.5123 - val_acc: 0.7323
#
# Epoch 00045: val_acc did not improve from 0.74542
# Epoch 46/250
# 62820/62820 [==============================] - 30s 479us/step - loss: 0.4069 - acc: 0.8028 - val_loss: 0.4907 - val_acc: 0.7494
#
# Epoch 00046: val_acc improved from 0.74542 to 0.74943, saving model to models\time.model
250
# 62820/62820 [==============================] - 31s 500us/step - loss: 0.1279 - acc: 0.9432 - val_loss: 0.5515 - val_acc: 0.7873
#
# Epoch 00132: val_acc did not improve from 0.79628
# Epoch 133/250
# 62820/62820 [==============================] - 31s 499us/step - loss: 0.1244 - acc: 0.9449 - val_loss: 0.5636 - val_acc: 0.7846
#
# Epoch 00133: val_acc did not improve from 0.79628
# Epoch 134/250
# 62820/62820 [==============================] - 32s 504us/step - loss: 0.1236 - acc: 0.9451 - val_loss: 0.5376 - val_acc: 0.7879
#
# Epoch 00134: val_acc did not improve from 0.79628
# Epoch 135/250
# 62820/62820 [==============================] - 32s 502us/step - loss: 0.1360 - acc: 0.9415 - val_loss: 0.5606 - val_acc: 0.7748
#
# Epoch 00135: val_acc did not improve from 0.79628
# Epoch 136/250
# 62820/62820 [==============================] - 31s 501us/step - loss: 0.1259 - acc: 0.9456 - val_loss: 0.5599 - val_acc: 0.7855
#
# Epoch 00136: val_acc did not improve from 0.79628
# Epoch 137/250
# 62820/62820 [==============================] - 31s 499us/step - loss: 0.1148 - acc: 0.9476 - val_loss: 0.5837 - val_acc: 0.7734
#
# Epoch 00137: val_acc did not improve from 0.79628
# Epoch 138/250
# 62820/62820 [==============================] - 32s 502us/step - loss: 0.1200 - acc: 0.9481 - val_loss: 0.5648 - val_acc: 0.7854
#
# Epoch 00138: val_acc did not improve from 0.79628
# Epoch 139/250
# 62820/62820 [==============================] - 32s 502us/step - loss: 0.1251 - acc: 0.9452 - val_loss: 0.5576 - val_acc: 0.7665
#
# Epoch 00139: val_acc did not improve from 0.79628
# Epoch 140/250
# 62820/62820 [==============================] - 32s 507us/step - loss: 0.1201 - acc: 0.9469 - val_loss: 0.5684 - val_acc: 0.7711
#
# Epoch 00140: val_acc did not improve from 0.79628
# Epoch 141/250
# 62820/62820 [==============================] - 32s 504us/step - loss: 0.1300 - acc: 0.9437 - val_loss: 0.5131 - val_acc: 0.7748
#
# Epoch 00141: val_acc did not improve from 0.79628
# Epoch 142/250
# 62820/62820 [==============================] - 32s 503us/step - loss: 0.1217 - acc: 0.9470 - val_loss: 0.5917 - val_acc: 0.7632
#
# Epoch 00142: val_acc did not improve from 0.79628
# Epoch 143/250
# 62820/62820 [==============================] - 32s 511us/step - loss: 0.1097 - acc: 0.9501 - val_loss: 0.5782 - val_acc: 0.7827
#
# Epoch 00143: val_acc did not improve from 0.79628
# Epoch 144/250
# 62820/62820 [==============================] - 32s 507us/step - loss: 0.1183 - acc: 0.9468 - val_loss: 0.5963 - val_acc: 0.7754
#
# Epoch 00144: val_acc did not improve from 0.79628
# Epoch 145/250
# 62820/62820 [==============================] - 32s 503us/step - loss: 0.1125 - acc: 0.9494 - val_loss: 0.6879 - val_acc: 0.7658
#
# Epoch 00145: val_acc did not improve from 0.79628
# Epoch 146/250
# 62820/62820 [==============================] - 32s 502us/step - loss: 0.1156 - acc: 0.9482 - val_loss: 0.5779 - val_acc: 0.7850
#
# Epoch 00146: val_acc did not improve from 0.79628
# Epoch 147/250
# 62820/62820 [==============================] - 32s 502us/step - loss: 0.1105 - acc: 0.9504 - val_loss: 0.5937 - val_acc: 0.7926
#
# Epoch 00147: val_acc did not improve from 0.79628
# Epoch 148/250
# 62820/62820 [==============================] - 31s 500us/step - loss: 0.1202 - acc: 0.9466 - val_loss: 0.5603 - val_acc: 0.7824
#
# Epoch 00148: val_acc did not improve from 0.79628
# Epoch 149/250
# 62820/62820 [==============================] - 32s 507us/step - loss: 0.1232 - acc: 0.9455 - val_loss: 0.5147 - val_acc: 0.7777
#
# Epoch 00149: val_acc did not improve from 0.79628
# Epoch 150/250
# 62820/62820 [==============================] - 31s 501us/step - loss: 0.
250
# 62820/62820 [==============================] - 32s 515us/step - loss: 0.0918 - acc: 0.9587 - val_loss: 0.5621 - val_acc: 0.7908
#
# Epoch 00187: val_acc did not improve from 0.79864
# Epoch 188/250
# 62820/62820 [==============================] - 32s 516us/step - loss: 0.0869 - acc: 0.9602 - val_loss: 0.6338 - val_acc: 0.7926
#
# Epoch 00188: val_acc did not improve from 0.79864
# Epoch 189/250
# 62820/62820 [==============================] - 32s 510us/step - loss: 0.0978 - acc: 0.9572 - val_loss: 0.5626 - val_acc: 0.7877
#
# Epoch 00189: val_acc did not improve from 0.79864
# Epoch 190/250
# 62820/62820 [==============================] - 32s 512us/step - loss: 0.0924 - acc: 0.9588 - val_loss: 0.6428 - val_acc: 0.7801
#
# Epoch 00190: val_acc did not improve from 0.79864
# Epoch 191/250
# 62820/62820 [==============================] - 32s 515us/step - loss: 0.0845 - acc: 0.9624 - val_loss: 0.6089 - val_acc: 0.7917
#
# Epoch 00191: val_acc did not improve from 0.79864
# Epoch 192/250
# 62820/62820 [==============================] - 32s 516us/step - loss: 0.0927 - acc: 0.9584 - val_loss: 0.6595 - val_acc: 0.7798
#
# Epoch 00192: val_acc did not improve from 0.79864
# Epoch 193/250
# 62820/62820 [==============================] - 32s 510us/step - loss: 0.0862 - acc: 0.9606 - val_loss: 0.6386 - val_acc: 0.7825
#
# Epoch 00193: val_acc did not improve from 0.79864
# Epoch 194/250
# 62820/62820 [==============================] - 32s 512us/step - loss: 0.0869 - acc: 0.9602 - val_loss: 0.5910 - val_acc: 0.7780
#
# Epoch 00194: val_acc did not improve from 0.79864
# Epoch 195/250
# 62820/62820 [==============================] - 33s 518us/step - loss: 0.0891 - acc: 0.9597 - val_loss: 0.5723 - val_acc: 0.7935
#
# Epoch 00195: val_acc did not improve from 0.79864
# Epoch 196/250
# 62820/62820 [==============================] - 32s 514us/step - loss: 0.0894 - acc: 0.9587 - val_loss: 0.6804 - val_acc: 0.7933
#
# Epoch 00196: val_acc did not improve from 0.79864
# Epoch 197/250
# 62820/62820 [==============================] - 33s 519us/step - loss: 0.0875 - acc: 0.9603 - val_loss: 0.5932 - val_acc: 0.7875
#
# Epoch 00197: val_acc did not improve from 0.79864
# Epoch 198/250
# 62820/62820 [==============================] - 32s 516us/step - loss: 0.0866 - acc: 0.9606 - val_loss: 0.5948 - val_acc: 0.7834
#
# Epoch 00198: val_acc did not improve from 0.79864
# Epoch 199/250
# 62820/62820 [==============================] - 33s 517us/step - loss: 0.0885 - acc: 0.9600 - val_loss: 0.5612 - val_acc: 0.7903
#
# Epoch 00199: val_acc did not improve from 0.79864
# Epoch 200/250
# 62820/62820 [==============================] - 33s 519us/step - loss: 0.1022 - acc: 0.9555 - val_loss: 0.5634 - val_acc: 0.7827
#
# Epoch 00200: val_acc did not improve from 0.79864
# Epoch 201/250
# 62820/62820 [==============================] - 33s 524us/step - loss: 0.0821 - acc: 0.9628 - val_loss: 0.6136 - val_acc: 0.7945
#
# Epoch 00201: val_acc did not improve from 0.79864
# Epoch 202/250
# 62820/62820 [==============================] - 33s 518us/step - loss: 0.0850 - acc: 0.9618 - val_loss: 0.5966 - val_acc: 0.7847
#
# Epoch 00202: val_acc did not improve from 0.79864
# Epoch 203/250
# 62820/62820 [==============================] - 34s 544us/step - loss: 0.0827 - acc: 0.9623 - val_loss: 0.6018 - val_acc: 0.7946
#
# Epoch 00203: val_acc did not improve from 0.79864
# Epoch 204/250
# 62820/62820 [==============================] - 32s 514us/step - loss: 0.0840 - acc: 0.9621 - val_loss: 0.5884 - val_acc: 0.7888
#
# Epoch 00204: val_acc did not improve from 0.79864
# Epoch 205/250
# 62820/62820 [==============================] - 32s 506us/step - loss: 0.0833 - acc: 0.9614 - val_loss: 0.6504 - val_acc: 0.7822
#
# Epoch 00205: val_acc did not improve from 0.79864
# Epoch 206/250
# 62820/62820 [==============================] - 32s 517us/step - loss: 0.0869 - acc: 0.9607 - val_loss: 0.5900 - val_acc: 0.7926
#
# Epoch 00206: val_acc did not improve from 0.79864
# Epoch 207/250
# 62820/62820 [==============================] - 32s 515us/step - loss: 0.0909 - acc: 0.9599 - val_loss: 0.5648 - val_acc: 0.7918
#
# Epoch 00207: val_acc did not improve from 0.79864
# Epoch 208/250
# 62820/62820 [==============================] - 32s 515us/step - loss: 0.0840 - acc: 0.9625 - val_loss: 0.6119 - val_acc: 0.7946
#
# Epoch 00208: val_acc did not improve from 0.79864
# Epoch 209/250
# 62820/62820 [==============================] - 32s 512us/step - loss: 0.0852 - acc: 0.9619 - val_loss: 0.5692 - val_acc: 0.7917
#
# Epoch 00209: val_acc did not improve from 0.79864
# Epoch 210/250
# 62820/62820 [==============================] - 32s 512us/step - loss: 0.0807 - acc: 0.9632 - val_loss: 0.5790 - val_acc: 0.7960
#
# Epoch 00210: val_acc did not improve from 0.79864
# Epoch 211/250
# 62820/62820 [==============================] - 32s 516us/step - loss: 0.0828 - acc: 0.9623 - val_loss: 0.5596 - val_acc: 0.7915
#
# Epoch 00211: val_acc did not improve from 0.79864
# Epoch 212/250
# 62820/62820 [==============================] - 32s 515us/step - loss: 0.0810 - acc: 0.9630 - val_loss: 0.5873 - val_acc: 0.7913
#
# Epoch 00212: val_acc did not improve from 0.79864
# Epoch 213/250
# 62820/62820 [==============================] - 33s 521us/step - loss: 0.0752 - acc: 0.9650 - val_loss: 0.6414 - val_acc: 0.7962
#
# Epoch 00213: val_acc did not improve from 0.79864
# Epoch 214/250
# 62820/62820 [==============================] - 32s 511us/step - loss: 0.0811 - acc: 0.9630 - val_loss: 0.5643 - val_acc: 0.8019
#
# Epoch 00214: val_acc improved from 0.79864 to 0.80193, saving model to models\time.model
# Epoch 215/250
# 62820/62820 [==============================] - 32s 517us/step - loss: 0.0862 - acc: 0.9612 - val_loss: 0.5697 - val_acc: 0.7892
#
# Epoch 00215: val_acc did not improve from 0.80193
# Epoch 216/250
# 62820/62820 [==============================] - 33s 521us/step - loss: 0.0769 - acc: 0.9642 - val_loss: 0.6017 - val_acc: 0.8088
#
# Epoch 00216: val_acc improved from 0.80193 to 0.80881, saving model to models\time.model
# Epoch 217/250
# 62820/62820 [==============================] - 33s 518us/step - loss: 0.0832 - acc: 0.9623 - val_loss: 0.5566 - val_acc: 0.7828
#
# Epoch 00217: val_acc did not improve from 0.80881
# Epoch 218/250
# 62820/62820 [==============================] - 33s 519us/step - loss: 0.0770 - acc: 0.9649 - val_loss: 0.6899 - val_acc: 0.7686
#
# Epoch 00218: val_acc did not improve from 0.80881
# Epoch 219/250
# 62820/62820 [==============================] - 33s 525us/step - loss: 0.0809 - acc: 0.9634 - val_loss: 0.5900 - val_acc: 0.7960
#
# Epoch 00219: val_acc did not improve from 0.80881
# Epoch 220/250
# 62820/62820 [==============================] - 33s 524us/step - loss: 0.0785 - acc: 0.9643 - val_loss: 0.6070 - val_acc: 0.7933
#
# Epoch 00220: val_acc did not improve from 0.80881
# Epoch 221/250
# 62820/62820 [==============================] - 33s 524us/step - loss: 0.0807 - acc: 0.9634 - val_loss: 0.6158 - val_acc: 0.8077
#
# Epoch 00221: val_acc did not improve from 0.80881
# Epoch 222/250
# 62820/62820 [==============================] - 33s 528us/step - loss: 0.0763 - acc: 0.9656 - val_loss: 0.6358 - val_acc: 0.8014
#
# Epoch 00222: val_acc did not improve from 0.80881
# Epoch 223/250
# 62820/62820 [==============================] - 33s 519us/step - loss: 0.0829 - acc: 0.9625 - val_loss: 0.5907 - val_acc: 0.7858
#
# Epoch 00223: val_acc did not improve from 0.80881
# Epoch 224/250
# 62820/62820 [==============================] - 33s 527us/step - loss: 0.0761 - acc: 0.9657 - val_loss: 0.6464 - val_acc: 0.7990
#
# Epoch 00224: val_acc did not improve from 0.80881
# Epoch 225/250
# 62820/62820 [==============================] - 33s 527us/step - loss: 0.0810 - acc: 0.9641 - val_loss: 0.5859 - val_acc: 0.8014
#
# Epoch 00225: val_acc did not improve from 0.80881
# Epoch 226/250
# 62820/62820 [==============================] - 33s 530us/step - loss: 0.0812 - acc: 0.9622 - val_loss: 0.5740 - val_acc: 0.8039
#
# Epoch 00226: val_acc did not improve from 0.80881
# Epoch 227/250
# 62820/62820 [==============================] - 33s 527us/step - loss: 0.0838 - acc: 0.9630 - val_loss: 0.5477 - val_acc: 0.8022
#
# Epoch 00227: val_acc did not improve from 0.80881
# Epoch 228/250
# 62820/62820 [==============================] - 33s 526us/step - loss: 0.0700 - acc: 0.9667 - val_loss: 0.6289 - val_acc: 0.7912
#
# Epoch 00228: val_acc did not improve from 0.80881
# Epoch 229/250
# 62820/62820 [==============================] - 33s 524us/step - loss: 0.0879 - acc: 0.9617 - val_loss: 0.6140 - val_acc: 0.8004
#
# Epoch 00229: val_acc did not improve from 0.80881
# Epoch 230/250
# 62820/62820 [==============================] - 33s 524us/step - loss: 0.0740 - acc: 0.9665 - val_loss: 0.6903 - val_acc: 0.7735
#
# Epoch 00230: val_acc did not improve from 0.80881
# Epoch 231/250
# 62820/62820 [==============================] - 33s 523us/step - loss: 0.0814 - acc: 0.9633 - val_loss: 0.5795 - val_acc: 0.7948
#
# Epoch 00231: val_acc did not improve from 0.80881
# Epoch 232/250
# 62820/62820 [==============================] - 33s 524us/step - loss: 0.0757 - acc: 0.9663 - val_loss: 0.6017 - val_acc: 0.7950
#
# Epoch 00232: val_acc did not improve from 0.80881
# Epoch 233/250
# 62820/62820 [==============================] - 34s 534us/step - loss: 0.0820 - acc: 0.9629 - val_loss: 0.5766 - val_acc: 0.7999
#
# Epoch 00233: val_acc did not improve from 0.80881
# Epoch 234/250
# 62820/62820 [==============================] - 33s 527us/step - loss: 0.0714 - acc: 0.9673 - val_loss: 0.6271 - val_acc: 0.7973
#
# Epoch 00234: val_acc did not improve from 0.80881
# Epoch 235/250
# 62820/62820 [==============================] - 33s 526us/step - loss: 0.1251 - acc: 0.9454 - val_loss: 0.5523 - val_acc: 0.7982
#
# Epoch 00235: val_acc did not improve from 0.80881
# Epoch 236/250
# 62820/62820 [==============================] - 33s 525us/step - loss: 0.0766 - acc: 0.9657 - val_loss: 0.5919 - val_acc: 0.8039
#
# Epoch 00236: val_acc did not improve from 0.80881
# Epoch 237/250
# 62820/62820 [==============================] - 33s 532us/step - loss: 0.0726 - acc: 0.9667 - val_loss: 0.5485 - val_acc: 0.7983
#
# Epoch 00237: val_acc did not improve from 0.80881
# Epoch 238/250
# 62820/62820 [==============================] - 34s 534us/step - loss: 0.0777 - acc: 0.9649 - val_loss: 0.5994 - val_acc: 0.7964
#
# Epoch 00238: val_acc did not improve from 0.80881
# Epoch 239/250
# 62820/62820 [==============================] - 33s 521us/step - loss: 0.0712 - acc: 0.9678 - val_loss: 0.6310 - val_acc: 0.8039
#
# Epoch 00239: val_acc did not improve from 0.80881
# Epoch 240/250
# 62820/62820 [==============================] - 33s 531us/step - loss: 0.0863 - acc: 0.9621 - val_loss: 0.6067 - val_acc: 0.7957
#
# Epoch 00240: val_acc did not improve from 0.80881
# Epoch 241/250
# 62820/62820 [==============================] - 33s 523us/step - loss: 0.0775 - acc: 0.9658 - val_loss: 0.6037 - val_acc: 0.7887
#
# Epoch 00241: val_acc did not improve from 0.80881
# Epoch 242/250
# 62820/62820 [==============================] - 33s 531us/step - loss: 0.0736 - acc: 0.9666 - val_loss: 0.6092 - val_acc: 0.8032
#
# Epoch 00242: val_acc did not improve from 0.80881
# Epoch 243/250
# 62820/62820 [==============================] - 34s 535us/step - loss: 0.0751 - acc: 0.9663 - val_loss: 0.5924 - val_acc: 0.7918
#
# Epoch 00243: val_acc did not improve from 0.80881
# Epoch 244/250
# 62820/62820 [==============================] - 33s 527us/step - loss: 0.0692 - acc: 0.9681 - val_loss: 0.6312 - val_acc: 0.7884
#
# Epoch 00244: val_acc did not improve from 0.80881
# Epoch 245/250
# 62820/62820 [==============================] - 33s 531us/step - loss: 0.0799 - acc: 0.9637 - val_loss: 0.5947 - val_acc: 0.7960
#
# Epoch 00245: val_acc did not improve from 0.80881
# Epoch 246/250
# 62820/62820 [==============================] - 34s 542us/step - loss: 0.0852 - acc: 0.9631 - val_loss: 0.5954 - val_acc: 0.7888
#
# Epoch 00246: val_acc did not improve from 0.80881
# Epoch 247/250
# 62820/62820 [==============================] - 34s 535us/step - loss: 0.0701 - acc: 0.9679 - val_loss: 0.6086 - val_acc: 0.7941
#
# Epoch 00247: val_acc did not improve from 0.80881
# Epoch 248/250
# 62820/62820 [==============================] - 34s 538us/step - loss: 0.0727 - acc: 0.9667 - val_loss: 0.6142 - val_acc: 0.7826
#
# Epoch 00248: val_acc did not improve from 0.80881
# Epoch 249/250
# 62820/62820 [==============================] - 33s 525us/step - loss: 0.0773 - acc: 0.9647 - val_loss: 0.5900 - val_acc: 0.8043
#
# Epoch 00249: val_acc did not improve from 0.80881
# Epoch 250/250
# 62820/62820 [==============================] - 34s 540us/step - loss: 0.0733 - acc: 0.9669 - val_loss: 0.6082 - val_acc: 0.7958
#
# Epoch 00250: val_acc did not improve from 0.80881

# %%
fig, axes = plt.subplots(nrows=1, ncols=1, sharex=False, sharey=True, figsize=(20,8))

# Plot accuracy per iteration
plt.plot(model.history.history['acc'][:50], label='acc')
plt.plot(model.history.history['val_acc'][:50], label='val_acc')
plt.legend()

plt.title('Custom Built LSTM RNN Model\'s Training Analysis on the sickness and non-sickness Audio Data', size=16)
plt.xlabel("Epochs")
plt.ylabel("accuracy reached")

plt.show()
